# %% [markdown]
# # SQL comparison notebooks <dataset_name>
# This data analysis was automatically generated using the TAP algorithm.

# %%
import sqlalchemy
sqlalchemy.create_engine("postgresql://localhost:5432/covid?user=marcel&password=1598marcel")
# %load_ext sql
# %sql postgresql://localhost:5432/covid?user=marcel&password=1598marcel
# %config SqlMagic.displaycon=False
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Query 1
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" H vs Z
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = H", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = Z"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'H'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 2 rows affected.
# [('Châteaugiron', Decimal('309785'), Decimal('7184')),
#  ('Dinan', Decimal('472973'), Decimal('15041'))]

# %% [markdown]
# ### Query 2
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" Z vs H
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = Z", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = H"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'H'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 2 rows affected.
# [('Châteaugiron', Decimal('7184'), Decimal('309785')),
#  ('Dinan', Decimal('15041'), Decimal('472973'))]

# %% [markdown]
# ### Query 3
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" Z vs _
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = Z", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = _"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = '_'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 2 rows affected.
# [('Châteaugiron', Decimal('7184'), Decimal('4457')),
#  ('Dinan', Decimal('15041'), Decimal('12864'))]

# %% [markdown]
# ### Query 4
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" _ vs Z
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = _", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = Z"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = '_'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 2 rows affected.
# [('Châteaugiron', Decimal('4457'), Decimal('7184')),
#  ('Dinan', Decimal('12864'), Decimal('15041'))]

# %% [markdown]
# ### Query 5
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" Z vs A
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = Z", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = A"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'A'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 1 rows affected.
# [('Dinan', Decimal('15041'), Decimal('19348'))]

# %% [markdown]
# ### Query 6
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" A vs Z
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = A", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = Z"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'A'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 1 rows affected.
# [('Dinan', Decimal('19348'), Decimal('15041'))]

# %% [markdown]
# ### Query 7
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" Z vs D
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = Z", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = D"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'D'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 0 rows affected.
# []

# %% [markdown]
# ### Query 8
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" D vs Z
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = D", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = Z"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'D'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 0 rows affected.
# []

# %% [markdown]
# ### Query 9
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" Z vs F
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = Z", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = F"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'F'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 2 rows affected.
# [('Châteaugiron', Decimal('7184'), Decimal('2310')),
#  ('Dinan', Decimal('15041'), Decimal('349'))]

# %% [markdown]
# ### Query 10
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "Type IRIS" F vs Z
# grouped by "Nom Commune"

# %%
# %%sql
# select t1."Nom Commune",
#        t1.measure1 as "Sum(Conso totale (MWh)) for Type IRIS = F", t2.measure2 as "Sum(Conso totale (MWh)) for Type IRIS = Z"
# from
#   (select "Type IRIS", "Nom Commune", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "Type IRIS" = 'F'
#    group by "Type IRIS", "Nom Commune") t1,
#   (select "Type IRIS", "Nom Commune",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "Type IRIS" = 'Z'
#    group by "Type IRIS", "Nom Commune") t2
# where t1."Nom Commune" = t2."Nom Commune" order by "Nom Commune";
# Out:
# 2 rows affected.
# [('Châteaugiron', Decimal('2310'), Decimal('7184')),
#  ('Dinan', Decimal('349'), Decimal('15041'))]

# %% [markdown]
# ### Query 11
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" PRO vs ENT
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('19969'), Decimal('38870')),
#  ('CA', Decimal('8125210'), Decimal('28096371')),
#  ('CC', Decimal('11799282'), Decimal('43545248')),
#  ('CU', Decimal('475454'), Decimal('1713484')),
#  ('ME', Decimal('2036532'), Decimal('7655343')),
#  ('nd', Decimal('106362'), Decimal('423839')),
#  ('ZZ', Decimal('10168'), Decimal('91808'))]

# %% [markdown]
# ### Query 12
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" PRO vs ENT
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('19969'), Decimal('38870')),
#  ('CA', Decimal('8125210'), Decimal('28096371')),
#  ('CC', Decimal('11799282'), Decimal('43545248')),
#  ('CU', Decimal('475454'), Decimal('1713484')),
#  ('ME', Decimal('2036532'), Decimal('7655343')),
#  ('nd', Decimal('106362'), Decimal('423839')),
#  ('ZZ', Decimal('10168'), Decimal('91808'))]

# %% [markdown]
# ### Query 13
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" PRO vs ENT
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('19969'), Decimal('38870')),
#  ('CA', Decimal('8125210'), Decimal('28096371')),
#  ('CC', Decimal('11799282'), Decimal('43545248')),
#  ('CU', Decimal('475454'), Decimal('1713484')),
#  ('ME', Decimal('2036532'), Decimal('7655343')),
#  ('nd', Decimal('106362'), Decimal('423839')),
#  ('ZZ', Decimal('10168'), Decimal('91808'))]

# %% [markdown]
# ### Query 14
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" ENT vs PRO
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('38870'), Decimal('19969')),
#  ('CA', Decimal('28096371'), Decimal('8125210')),
#  ('CC', Decimal('43545248'), Decimal('11799282')),
#  ('CU', Decimal('1713484'), Decimal('475454')),
#  ('ME', Decimal('7655343'), Decimal('2036532')),
#  ('nd', Decimal('423839'), Decimal('106362')),
#  ('ZZ', Decimal('91808'), Decimal('10168'))]

# %% [markdown]
# ### Query 15
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" ENT vs PRO
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('38870'), Decimal('19969')),
#  ('CA', Decimal('28096371'), Decimal('8125210')),
#  ('CC', Decimal('43545248'), Decimal('11799282')),
#  ('CU', Decimal('1713484'), Decimal('475454')),
#  ('ME', Decimal('7655343'), Decimal('2036532')),
#  ('nd', Decimal('423839'), Decimal('106362')),
#  ('ZZ', Decimal('91808'), Decimal('10168'))]

# %% [markdown]
# ### Query 16
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" ENT vs PRO
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('38870'), Decimal('19969')),
#  ('CA', Decimal('28096371'), Decimal('8125210')),
#  ('CC', Decimal('43545248'), Decimal('11799282')),
#  ('CU', Decimal('1713484'), Decimal('475454')),
#  ('ME', Decimal('7655343'), Decimal('2036532')),
#  ('nd', Decimal('423839'), Decimal('106362')),
#  ('ZZ', Decimal('91808'), Decimal('10168'))]

# %% [markdown]
# ### Query 17
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" ENT vs PRO
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('38870'), Decimal('19969')),
#  ('CA', Decimal('28096371'), Decimal('8125210')),
#  ('CC', Decimal('43545248'), Decimal('11799282')),
#  ('CU', Decimal('1713484'), Decimal('475454')),
#  ('ME', Decimal('7655343'), Decimal('2036532')),
#  ('nd', Decimal('423839'), Decimal('106362')),
#  ('ZZ', Decimal('91808'), Decimal('10168'))]

# %% [markdown]
# ### Query 18
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" ENT vs PRO
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('38870'), Decimal('19969')),
#  ('CA', Decimal('28096371'), Decimal('8125210')),
#  ('CC', Decimal('43545248'), Decimal('11799282')),
#  ('CU', Decimal('1713484'), Decimal('475454')),
#  ('ME', Decimal('7655343'), Decimal('2036532')),
#  ('nd', Decimal('423839'), Decimal('106362')),
#  ('ZZ', Decimal('91808'), Decimal('10168'))]

# %% [markdown]
# ### Query 19
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" ENT vs PRO
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('38870'), Decimal('19969')),
#  ('CA', Decimal('28096371'), Decimal('8125210')),
#  ('CC', Decimal('43545248'), Decimal('11799282')),
#  ('CU', Decimal('1713484'), Decimal('475454')),
#  ('ME', Decimal('7655343'), Decimal('2036532')),
#  ('nd', Decimal('423839'), Decimal('106362')),
#  ('ZZ', Decimal('91808'), Decimal('10168'))]

# %% [markdown]
# ### Query 20
#
# For measure Sum of "Conso totale (MWh)"
# Comparing "CODE CATEGORIE CONSOMMATION" PRO vs ENT
# grouped by "Type EPCI"

# %%
# %%sql
# select t1."Type EPCI",
#        t1.measure1 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = PRO", t2.measure2 as "Sum(Conso totale (MWh)) for CODE CATEGORIE CONSOMMATION = ENT"
# from
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI", sum("Conso totale (MWh)") as measure1
#    from "conso_iris"
#    where  "CODE CATEGORIE CONSOMMATION" = 'PRO'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t1,
#   (select "CODE CATEGORIE CONSOMMATION", "Type EPCI",sum("Conso totale (MWh)") as measure2
#    from "conso_iris"
#    where "CODE CATEGORIE CONSOMMATION" = 'ENT'
#    group by "CODE CATEGORIE CONSOMMATION", "Type EPCI") t2
# where t1."Type EPCI" = t2."Type EPCI" order by "Type EPCI";
# Out:
# 7 rows affected.
# [('0', Decimal('19969'), Decimal('38870')),
#  ('CA', Decimal('8125210'), Decimal('28096371')),
#  ('CC', Decimal('11799282'), Decimal('43545248')),
#  ('CU', Decimal('475454'), Decimal('1713484')),
#  ('ME', Decimal('2036532'), Decimal('7655343')),
#  ('nd', Decimal('106362'), Decimal('423839')),
#  ('ZZ', Decimal('10168'), Decimal('91808'))]
